# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
# !pip install 'scanpy[leiden]'
# Out:
# Collecting scanpy[leiden]
#   Downloading scanpy-1.12.2-py3-none-any.whl.metadata (8.5 kB)
# Collecting anndata>=0.10.8 (from scanpy[leiden])
#   Downloading anndata-0.12.19-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from scanpy[leiden]) (2026.2.25)
# Collecting fast-array-utils>=1.4 (from fast-array-utils[accel,sparse]>=1.4->scanpy[leiden])
#   Downloading fast_array_utils-1.4.1-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: h5py>=3.11 in /usr/local/lib/python3.12/dist-packages (from scanpy[leiden]) (3.16.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from scanpy[leiden]) (1.5.3)
# Collecting legacy-api-wrap>=1.5 (from scanpy[leiden])
#   Downloading legacy_api_wrap-1.5-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: matplotlib!=3.11,!=3.11.0rc1,!=3.11.0rc2,>=3.10 in /usr/local/lib/python3.12/dist-packages (from scanpy[leiden]) (3.10.0)
# Requirement already satisfied: natsort in /usr/local/lib/python3.12/dist-packages (from scanpy[leiden]) (8.4.0)
# Requirement already satisfied: networkx>=2.8.8 in /usr/local/lib/python3.12/dist-packages (from scanpy[leiden]) (3.6.1)
# Requirement already satisfied: numba>=0.60 in /usr/local/lib/python3.12/dist-packages (from scanpy[leiden]) (0.60.0)
# Requirement already satisfied: numpy>=2 in /usr/local/lib/python3.12/dist-packages (from scanpy[leiden]) (2.0.2)
# Requirement already satisfied: packaging>=25 in /usr/local/lib/python3.12/dist-packages (from scanpy[leiden]) (26.0)
# Collecting pandas>=2.3 (from scanpy[leiden])
#   Downloading pandas-3.0.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 8.2 MB/s eta 0:00:00
# Requirement already satisfied: patsy in /usr/local/lib/python3.12/dist-packages (from scanpy[leiden]) (1.0.2)
# Requirement already satisfied: pynndescent>=0.5.13 in /usr/local/lib/python3.12/dist-packages (from scanpy[leiden]) (0.6.0)
# Requirement already satisfied: scikit-learn>=1.6 in /usr/local/lib/python3.12/dist-packages (from scanpy[leiden]) (1.6.1)
# Requirement already satisfied: scipy>=1.13 in /usr/local/lib/python3.12/dist-packages (from scanpy[leiden]) (1.16.3)
# Collecting scverse-misc>=0.0.6 (from scanpy[leiden])
#   Downloading scverse_misc-0.1.1-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: seaborn>=0.13.2 in /usr/local/lib/python3.12/dist-packages (from scanpy[leiden]) (0.13.2)
# Collecting session-info2 (from scanpy[leiden])
#   Downloading session_info2-0.4.1-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: statsmodels>=0.14.5 in /usr/local/lib/python3.12/dist-packages (from scanpy[leiden]) (0.14.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from scanpy[leiden]) (4.67.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from scanpy[leiden]) (4.15.0)
# Collecting umap-learn>=0.5.12 (from scanpy[leiden])
#   Downloading umap_learn-0.5.12-py3-none-any.whl.metadata (24 kB)
# Collecting igraph>=0.10.8 (from scanpy[leiden])
#   Downloading igraph-1.0.0-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (4.4 kB)
# Collecting leidenalg>=0.10.1 (from scanpy[leiden])
#   Downloading leidenalg-0.12.0-cp38-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (10 kB)
# Collecting array-api-compat>=1.7.1 (from anndata>=0.10.8->scanpy[leiden])
#   Downloading array_api_compat-1.15.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting pandas>=2.3 (from scanpy[leiden])
#   Downloading pandas-2.3.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 15.6 MB/s eta 0:00:00
# Collecting zarr!=3.0.*,>=2.18.7 (from anndata>=0.10.8->scanpy[leiden])
#   Downloading zarr-3.2.1-py3-none-any.whl.metadata (8.7 kB)
# Collecting texttable>=1.6.2 (from igraph>=0.10.8->scanpy[leiden])
#   Downloading texttable-1.7.0-py2.py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.11,!=3.11.0rc1,!=3.11.0rc2,>=3.10->scanpy[leiden]) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.11,!=3.11.0rc1,!=3.11.0rc2,>=3.10->scanpy[leiden]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.11,!=3.11.0rc1,!=3.11.0rc2,>=3.10->scanpy[leiden]) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.11,!=3.11.0rc1,!=3.11.0rc2,>=3.10->scanpy[leiden]) (1.5.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.11,!=3.11.0rc1,!=3.11.0rc2,>=3.10->scanpy[leiden]) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.11,!=3.11.0rc1,!=3.11.0rc2,>=3.10->scanpy[leiden]) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.11,!=3.11.0rc1,!=3.11.0rc2,>=3.10->scanpy[leiden]) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.60->scanpy[leiden]) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.3->scanpy[leiden]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.3->scanpy[leiden]) (2025.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.6->scanpy[leiden]) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib!=3.11,!=3.11.0rc1,!=3.11.0rc2,>=3.10->scanpy[leiden]) (1.17.0)
# Collecting donfig>=0.8 (from zarr!=3.0.*,>=2.18.7->anndata>=0.10.8->scanpy[leiden])
#   Downloading donfig-0.8.1.post1-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: google-crc32c>=1.5 in /usr/local/lib/python3.12/dist-packages (from zarr!=3.0.*,>=2.18.7->anndata>=0.10.8->scanpy[leiden]) (1.8.0)
# Collecting numcodecs>=0.14 (from zarr!=3.0.*,>=2.18.7->anndata>=0.10.8->scanpy[leiden])
#   Downloading numcodecs-0.16.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from donfig>=0.8->zarr!=3.0.*,>=2.18.7->anndata>=0.10.8->scanpy[leiden]) (6.0.3)
# Downloading anndata-0.12.19-py3-none-any.whl (176 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.1/176.1 kB 28.2 MB/s eta 0:00:00
# Downloading fast_array_utils-1.4.1-py3-none-any.whl (39 kB)
# Downloading igraph-1.0.0-cp39-abi3-manylinux_2_28_x86_64.whl (5.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 114.8 MB/s eta 0:00:0000:01
# Downloading legacy_api_wrap-1.5-py3-none-any.whl (10 kB)
# Downloading leidenalg-0.12.0-cp38-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 37.9 MB/s eta 0:00:0000:01m
# Downloading pandas-2.3.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 133.2 MB/s eta 0:00:0000:010:01
# Downloading scverse_misc-0.1.1-py3-none-any.whl (22 kB)
# Downloading umap_learn-0.5.12-py3-none-any.whl (91 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.8/91.8 kB 16.9 MB/s eta 0:00:00
# Downloading scanpy-1.12.2-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 135.4 MB/s eta 0:00:00
# Downloading session_info2-0.4.1-py3-none-any.whl (17 kB)
# Downloading array_api_compat-1.15.0-py3-none-any.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 14.7 MB/s eta 0:00:00
# Downloading texttable-1.7.0-py2.py3-none-any.whl (10 kB)
# Downloading zarr-3.2.1-py3-none-any.whl (319 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.6/319.6 kB 48.6 MB/s eta 0:00:00
# Downloading donfig-0.8.1.post1-py3-none-any.whl (21 kB)
# Downloading numcodecs-0.16.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (9.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 148.5 MB/s eta 0:00:0000:01
# Installing collected packages: texttable, session-info2, numcodecs, legacy-api-wrap, igraph, fast-array-utils, donfig, array-api-compat, zarr, scverse-misc, pandas, leidenalg, anndata, umap-learn, scanpy
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
#   Attempting uninstall: umap-learn
#     Found existing installation: umap-learn 0.5.11
#     Uninstalling umap-learn-0.5.11:
#       Successfully uninstalled umap-learn-0.5.11
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.3 which is incompatible.
# Successfully installed anndata-0.12.19 array-api-compat-1.15.0 donfig-0.8.1.post1 fast-array-utils-1.4.1 igraph-1.0.0 legacy-api-wrap-1.5 leidenalg-0.12.0 numcodecs-0.16.5 pandas-2.3.3 scanpy-1.12.2 scverse-misc-0.1.1 session-info2-0.4.1 texttable-1.7.0 umap-learn-0.5.12 zarr-3.2.1

# %%
import scanpy as sc
import anndata as ad

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
